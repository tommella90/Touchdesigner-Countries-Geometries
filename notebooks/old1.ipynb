# %%
from shapely.geometry import MultiPolygon
import json
from shapely.geometry import shape, mapping
from shapely.ops import unary_union
from shapely.ops import transform
from pyproj import Transformer
import os
import csv

# %%
file = "..\\rawData\\countries.geoJson"

with open(file, 'r') as f:
    data = json.load(f)

# %%
file = "..\\rawData\\countries.geoJson"

# EPSG:4326 to EPSG:3857 transformer
transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

with open(file, 'r') as f:
    data = json.load(f)

minx_global, miny_global = float('inf'), float('inf')
maxx_global, maxy_global = float('-inf'), float('-inf')

for feature in data['features']:
    geom = shape(feature['geometry'])

    # Project to EPSG:3857 if needed
    geom = transform(transformer.transform, geom)

    minx, miny, maxx, maxy = geom.bounds

    minx_global = min(minx_global, minx)
    miny_global = min(miny_global, miny)
    maxx_global = max(maxx_global, maxx)
    maxy_global = max(maxy_global, maxy)

print("Global extent (EPSG:3857):")
print(f"  minx: {minx_global:.2f}")
print(f"  miny: {miny_global:.2f}")
print(f"  maxx: {maxx_global:.2f}")
print(f"  maxy: {maxy_global:.2f}")

# Compute global center and extent
center_x = (minx_global + maxx_global) / 2
center_y = (miny_global + maxy_global) / 2
extent = max(maxx_global - minx_global, maxy_global - miny_global)
print(f"  center_x: {center_x:.2f}, center_y: {center_y:.2f}")
print(f"  extent: {extent:.2f} meters")

# If you want to normalize to fit in [-1, 1] for example
desired_output_size = 2.0
scale_factor = extent / desired_output_size
print(f"Suggested scale factor: {scale_factor:.2f}")
# Out:
# Global extent (EPSG:3857):
#   minx: -20037508.34
#   miny: -242528680.94
#   maxx: 20037508.34
#   maxy: 18428920.36
#   center_x: 0.00, center_y: -112049880.29
#   extent: 260957601.31 meters
# Suggested scale factor: 130478800.65

# %% [markdown]
# ## Correct missing ISO

# %%
# list all features name where 'ISO3166-1-Alpha-3' == -99
missingIso = [
    feature['properties']['name'] for feature in data['features']
    if feature['properties']['ISO3166-1-Alpha-3'] == '-99'
]
missingIso

missingIso = {
    "France": "FRA",
    "Somaliland": "SOM",
    "Kosovo": "KOS",
}

# replace -99 with corresponding name
for feature in data['features']:
    if feature['properties']['name'] in missingIso:
        feature['properties']['ISO3166-1-Alpha-3'] = missingIso[feature['properties']['name']]

# %%
from shapely.geometry import shape, MultiPolygon, Polygon, mapping
from shapely.ops import transform
from pyproj import Transformer
import os, csv, json

def createCoordsFile(format="csv", idx=0, tolerance=0.02, output_dir='../processedData', crs="EPSG:4326"):

    if crs == "EPSG:4326":
        crs_path = "epsg4326"
    elif crs == "EPSG:3857":
        crs_path = "epsg3857"

    feature = data['features'][idx]
    iso3 = feature['properties']['ISO3166-1-Alpha-3']
    geometry = shape(feature['geometry'])

    # Reproject geometry if needed
    if crs == "EPSG:3857":
        transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)
        geometry = transform(transformer.transform, geometry)

    simplified_geom = geometry.simplify(tolerance, preserve_topology=True)

    # Ensure geometry is iterable
    if isinstance(simplified_geom, Polygon):
        polygons = [simplified_geom]
    elif isinstance(simplified_geom, MultiPolygon):
        polygons = list(simplified_geom.geoms)
    else:
        raise TypeError(f"Unsupported geometry type: {simplified_geom.geom_type}")

    # Create output folder
    tol_str = str(tolerance).replace('.', '_')
    output_dir = f'../processedData/{format}/{crs_path}/tol{tol_str}'
    os.makedirs(output_dir, exist_ok=True)

    if format == "csv":
        csv_file = os.path.join(output_dir, f'{iso3}.csv')
        with open(csv_file, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(['poly_idx', 'line_idx', 'lat', 'lon'] if crs == "EPSG:4326" else ['poly_idx', 'line_idx', 'y', 'x'])

            for poly_idx, polygon in enumerate(polygons):
                outline = polygon.boundary

                if outline.geom_type == 'MultiLineString':
                    lines = [list(line.coords) for line in outline.geoms]
                else:
                    lines = [list(outline.coords)]

                for line_idx, line in enumerate(lines):
                    for coord in line:
                        if isinstance(coord, (list, tuple)) and len(coord) == 2:
                            x, y = coord
                            writer.writerow([poly_idx, line_idx, y, x])
                        else:
                            print(f"Warning: Invalid coordinate format: {coord}")

    elif format == "json":
        outline_coords = []
        for polygon in polygons:
            outline = polygon.boundary
            if outline.geom_type == 'MultiLineString':
                outline_coords.extend([list(line.coords) for line in outline.geoms])
            else:
                outline_coords.append(list(outline.coords))

        with open(os.path.join(output_dir, f'{iso3}.json'), 'w') as f:
            json.dump({"coordinates": outline_coords}, f, indent=2)

    print(f"Created {iso3} at {os.path.join(output_dir, f'{iso3}.{format}')}")

# %%
from shapely.geometry import shape, MultiPolygon, Polygon
from shapely.ops import transform
from pyproj import Transformer
import os, json

def createCoordsFile(idx=0, tolerance=0.02, output_dir='../processedData', crs="EPSG:4326", format='json', normalize=False, scale_factor=50000):

    # Set CRS subfolder
    crs_path = "epsg4326" if crs == "EPSG:4326" else "epsg3857"

    feature = data['features'][idx]
    iso3 = feature['properties']['ISO3166-1-Alpha-3']
    geometry = shape(feature['geometry'])

    # Reproject geometry if needed
    if crs == "EPSG:3857":
        transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)
        geometry = transform(transformer.transform, geometry)

    simplified_geom = geometry.simplify(tolerance, preserve_topology=True)

    # Ensure geometry is iterable
    if isinstance(simplified_geom, Polygon):
        polygons = [simplified_geom]
    elif isinstance(simplified_geom, MultiPolygon):
        polygons = list(simplified_geom.geoms)
    else:
        raise TypeError(f"Unsupported geometry type: {simplified_geom.geom_type}")

    # Prepare output path
    tol_str = str(tolerance).replace('.', '_')
    output_dir = f'../processedData/{format}/{crs_path}/tol{tol_str}'

    if normalize:
        output_dir += f'_normalized_sf{scale_factor}'
    os.makedirs(output_dir, exist_ok=True)

    # Compute normalization parameters
    if normalize:
        bounds = simplified_geom.bounds  # (minx, miny, maxx, maxy)
        center_x = (bounds[0] + bounds[2]) / 2
        center_y = (bounds[1] + bounds[3]) / 2
        scale = 1 / scale_factor

    outline_coords = []

    for polygon in polygons:
        outline = polygon.boundary
        lines = outline.geoms if outline.geom_type == 'MultiLineString' else [outline]
        for line in lines:
            coords = list(line.coords)
            if normalize:
                coords = [((x - center_x) * scale, (y - center_y) * scale) for x, y in coords]
            outline_coords.append(coords)

    # Export to file
    output_path = os.path.join(output_dir, f'{iso3}.json')
    with open(output_path, 'w') as f:
        json.dump({"coordinates": outline_coords}, f, indent=2)

    print(f"Created {iso3} at {output_path}")

# %%
for i in range(len(data['features'])):
    createCoordsFile(format='json', idx=i, tolerance=0, output_dir='../processedData', normalize=True, scale_factor=scale_factor)
    createCoordsFile(format='json', crs="EPSG:3857", idx=i, tolerance=0, output_dir='../processedData', normalize=True, scale_factor=scale_factor)
# Out:
# Created IDN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\IDN.json
# Created IDN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\IDN.json
# Created MYS at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MYS.json
# Created MYS at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MYS.json
# Created CHL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CHL.json
# Created CHL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CHL.json
# Created BOL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BOL.json
# Created BOL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BOL.json
# Created PER at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PER.json
# Created PER at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PER.json
# Created ARG at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ARG.json
# Created ARG at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ARG.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created CYP at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CYP.json
# Created CYP at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CYP.json
# Created IND at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\IND.json
# Created IND at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\IND.json
# Created CHN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CHN.json
# Created CHN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CHN.json
# Created ISR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ISR.json
# Created ISR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ISR.json
# Created PSE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PSE.json
# Created PSE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PSE.json
# Created LBN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LBN.json
# Created LBN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LBN.json
# Created ETH at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ETH.json
# Created ETH at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ETH.json
# Created SSD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SSD.json
# Created SSD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SSD.json
# Created SOM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SOM.json
# Created SOM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SOM.json
# Created KEN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KEN.json
# Created KEN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KEN.json
# Created MWI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MWI.json
# Created MWI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MWI.json
# Created TZA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TZA.json
# Created TZA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TZA.json
# Created SYR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SYR.json
# Created SYR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SYR.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created SUR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SUR.json
# Created SUR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SUR.json
# Created GUY at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GUY.json
# Created GUY at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GUY.json
# Created KOR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KOR.json
# Created KOR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KOR.json
# Created PRK at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PRK.json
# Created PRK at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PRK.json
# Created MAR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MAR.json
# Created MAR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MAR.json
# Created ESH at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ESH.json
# Created ESH at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ESH.json
# Created CRI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CRI.json
# Created CRI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CRI.json
# Created NIC at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NIC.json
# Created NIC at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NIC.json
# Created COG at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\COG.json
# Created COG at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\COG.json
# Created COD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\COD.json
# Created COD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\COD.json
# Created BTN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BTN.json
# Created BTN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BTN.json
# Created UKR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\UKR.json
# Created UKR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\UKR.json
# Created BLR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BLR.json
# Created BLR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BLR.json
# Created NAM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NAM.json
# Created NAM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NAM.json
# Created ZAF at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ZAF.json
# Created ZAF at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ZAF.json
# Created MAF at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MAF.json
# Created MAF at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MAF.json
# Created SXM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SXM.json
# Created SXM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SXM.json
# Created OMN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\OMN.json
# Created OMN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\OMN.json
# Created UZB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\UZB.json
# Created UZB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\UZB.json
# Created KAZ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KAZ.json
# Created KAZ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KAZ.json
# Created TJK at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TJK.json
# Created TJK at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TJK.json
# Created LTU at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LTU.json
# Created LTU at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LTU.json
# Created BRA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BRA.json
# Created BRA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BRA.json
# Created URY at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\URY.json
# Created URY at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\URY.json
# Created MNG at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MNG.json
# Created MNG at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MNG.json
# Created RUS at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\RUS.json
# Created RUS at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\RUS.json
# Created CZE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CZE.json
# Created CZE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CZE.json
# Created DEU at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\DEU.json
# Created DEU at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\DEU.json
# Created EST at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\EST.json
# Created EST at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\EST.json
# Created LVA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LVA.json
# Created LVA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LVA.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created SWE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SWE.json
# Created SWE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SWE.json
# Created FIN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\FIN.json
# Created FIN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\FIN.json
# Created VNM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\VNM.json
# Created VNM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\VNM.json
# Created KHM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KHM.json
# Created KHM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KHM.json
# Created LUX at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LUX.json
# Created LUX at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LUX.json
# Created ARE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ARE.json
# Created ARE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ARE.json
# Created BEL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BEL.json
# Created BEL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BEL.json
# Created GEO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GEO.json
# Created GEO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GEO.json
# Created MKD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MKD.json
# Created MKD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MKD.json
# Created ALB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ALB.json
# Created ALB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ALB.json
# Created AZE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\AZE.json
# Created AZE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\AZE.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created TUR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TUR.json
# Created TUR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TUR.json
# Created ESP at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ESP.json
# Created ESP at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ESP.json
# Created LAO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LAO.json
# Created LAO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LAO.json
# Created KGZ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KGZ.json
# Created KGZ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KGZ.json
# Created ARM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ARM.json
# Created ARM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ARM.json
# Created DNK at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\DNK.json
# Created DNK at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\DNK.json
# Created LBY at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LBY.json
# Created LBY at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LBY.json
# Created TUN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TUN.json
# Created TUN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TUN.json
# Created ROU at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ROU.json
# Created ROU at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ROU.json
# Created HUN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\HUN.json
# Created HUN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\HUN.json
# Created SVK at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SVK.json
# Created SVK at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SVK.json
# Created POL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\POL.json
# Created POL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\POL.json
# Created IRL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\IRL.json
# Created IRL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\IRL.json
# Created GBR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GBR.json
# Created GBR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GBR.json
# Created GRC at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GRC.json
# Created GRC at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GRC.json
# Created ZMB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ZMB.json
# Created ZMB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ZMB.json
# Created SLE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SLE.json
# Created SLE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SLE.json
# Created GIN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GIN.json
# Created GIN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GIN.json
# Created LBR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LBR.json
# Created LBR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LBR.json
# Created CAF at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CAF.json
# Created CAF at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CAF.json
# Created SDN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SDN.json
# Created SDN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SDN.json
# Created DJI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\DJI.json
# Created DJI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\DJI.json
# Created ERI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ERI.json
# Created ERI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ERI.json
# Created AUT at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\AUT.json
# Created AUT at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\AUT.json
# Created IRQ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\IRQ.json
# Created IRQ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\IRQ.json
# Created ITA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ITA.json
# Created ITA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ITA.json
# Created CHE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CHE.json
# Created CHE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CHE.json
# Created IRN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\IRN.json
# Created IRN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\IRN.json
# Created NLD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NLD.json
# Created NLD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NLD.json
# Created LIE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LIE.json
# Created LIE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LIE.json
# Created CIV at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CIV.json
# Created CIV at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CIV.json
# Created SRB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SRB.json
# Created SRB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SRB.json
# Created MLI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MLI.json
# Created MLI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MLI.json
# Created SEN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SEN.json
# Created SEN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SEN.json
# Created NGA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NGA.json
# Created NGA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NGA.json
# Created BEN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BEN.json
# Created BEN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BEN.json
# Created AGO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\AGO.json
# Created AGO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\AGO.json
# Created HRV at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\HRV.json
# Created HRV at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\HRV.json
# Created SVN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SVN.json
# Created SVN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SVN.json
# Created QAT at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\QAT.json
# Created QAT at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\QAT.json
# Created SAU at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SAU.json
# Created SAU at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SAU.json
# Created BWA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BWA.json
# Created BWA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BWA.json
# Created ZWE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ZWE.json
# Created ZWE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ZWE.json
# Created PAK at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PAK.json
# Created PAK at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PAK.json
# Created BGR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BGR.json
# Created BGR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BGR.json
# Created THA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\THA.json
# Created THA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\THA.json
# Created SMR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SMR.json
# Created SMR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SMR.json
# Created HTI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\HTI.json
# Created HTI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\HTI.json
# Created DOM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\DOM.json
# Created DOM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\DOM.json
# Created TCD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TCD.json
# Created TCD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TCD.json
# Created KWT at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\KWT.json
# Created KWT at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\KWT.json
# Created SLV at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SLV.json
# Created SLV at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SLV.json
# Created GTM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GTM.json
# Created GTM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GTM.json
# Created TLS at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TLS.json
# Created TLS at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TLS.json
# Created BRN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BRN.json
# Created BRN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BRN.json
# Created MCO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MCO.json
# Created MCO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MCO.json
# Created DZA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\DZA.json
# Created DZA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\DZA.json
# Created MOZ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MOZ.json
# Created MOZ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MOZ.json
# Created SWZ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\SWZ.json
# Created SWZ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\SWZ.json
# Created BDI at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BDI.json
# Created BDI at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BDI.json
# Created RWA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\RWA.json
# Created RWA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\RWA.json
# Created MMR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MMR.json
# Created MMR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MMR.json
# Created BGD at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BGD.json
# Created BGD at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BGD.json
# Created AND at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\AND.json
# Created AND at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\AND.json
# Created AFG at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\AFG.json
# Created AFG at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\AFG.json
# Created MNE at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MNE.json
# Created MNE at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MNE.json
# Created BIH at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BIH.json
# Created BIH at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BIH.json
# Created UGA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\UGA.json
# Created UGA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\UGA.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created CUB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CUB.json
# Created CUB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CUB.json
# Created HND at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\HND.json
# Created HND at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\HND.json
# Created ECU at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\ECU.json
# Created ECU at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\ECU.json
# Created COL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\COL.json
# Created COL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\COL.json
# Created PRY at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PRY.json
# Created PRY at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PRY.json
# Created -99 at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\-99.json
# Created -99 at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\-99.json
# Created PRT at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PRT.json
# Created PRT at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PRT.json
# Created MDA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MDA.json
# Created MDA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MDA.json
# Created TKM at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TKM.json
# Created TKM at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TKM.json
# Created JOR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\JOR.json
# Created JOR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\JOR.json
# Created NPL at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NPL.json
# Created NPL at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NPL.json
# Created LSO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\LSO.json
# Created LSO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\LSO.json
# Created CMR at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CMR.json
# Created CMR at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CMR.json
# Created GAB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GAB.json
# Created GAB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GAB.json
# Created NER at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\NER.json
# Created NER at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\NER.json
# Created BFA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BFA.json
# Created BFA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BFA.json
# Created TGO at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\TGO.json
# Created TGO at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\TGO.json
# Created GHA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GHA.json
# Created GHA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GHA.json
# Created GNB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GNB.json
# Created GNB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GNB.json
# Created GIB at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\GIB.json
# Created GIB at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\GIB.json
# Created USA at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\USA.json
# Created USA at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\USA.json
# Created CAN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\CAN.json
# Created CAN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\CAN.json
# Created MEX at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\MEX.json
# Created MEX at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\MEX.json
# Created BLZ at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\BLZ.json
# Created BLZ at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\BLZ.json
# Created PAN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PAN.json
# Created PAN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\PAN.json
# Created VEN at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\VEN.json
# Created VEN at ../processedData/json/epsg3857/tol0_normalized_sf130478800.65253803\VEN.json
# Created PNG at ../processedData/json/epsg4326/tol0_normalized_sf130478800.65253803\PNG.json

# %%
# createCoordsFile(format='csv', idx=90, tolerance=0, output_dir='../processedData')
